# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn

# %%
df=pd.read_csv(r"C:\Users\situ\Desktop\EDA project\diamonds.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # train & test

# %%
y=df['price']
x=df.drop(columns=['price'])

# %%
x
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53794 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
xtrain
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 15385   0.29  Very Good     G    VVS1   61.6   56.0  4.24  4.27  2.62
# 4417    1.01       Good     E     SI2   63.9   58.0  6.37  6.31  4.05
# 16249   1.02      Ideal     G     VS2   61.4   55.0  6.48  6.51  3.99
# 21957   1.12    Premium     F    VVS2   62.4   59.0  6.58  6.66  4.13
# 27242   2.07      Ideal     G     SI2   62.2   54.0  8.16  8.21  5.09
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 23505   1.51       Good     H     VS1   59.1   58.0  7.48  7.52  4.43
# 23829   2.01    Premium     F     SI2   62.0   60.0  7.88  7.82  4.87
# 37243   0.43  Very Good     G    VVS2   61.7   56.0  4.84  4.88  2.99
# 27163   2.64      Ideal     H     SI2   62.3   55.0  8.88  8.83  5.52
# 48625   0.70       Good     E     SI1   64.4   58.0  5.48  5.52  3.54
#
# [43035 rows x 9 columns]

# %%
xcont=['carat','depth','table','x','y','z']
xordinal=['cut']
xnominal=['color','clarity']

# %% [markdown]
# # import libraries

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # pipeline  for - xcont

# %%
xcontpipeline=Pipeline(steps=[
    ('simpleimputer',SimpleImputer(strategy='median')),
    ('robustscaler',RobustScaler(),
    ('yeojhonson',PowerTransformer()))
])

# %% [markdown]
# # pipeline for - xnominal

# %%
xnominalpipeline=Pipeline(steps=[
    ('simpleImputer',SimpleImputer(strategy='most_frequent')),
    ('onehotencoder',OneHotEncoder(sparse_output=False,drop='frist'))
])

# %% [markdown]
# # pipeline for -xordinal

# %%
xordinalpipeline=Pipeline(steps=[
    ('simpleIncoder',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OrdinalEncoder(categories = [['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']))
])
# Out:
#   Cell In[41], line 3
#     ('ordinalencoder',OrdinalEncoder(categories = [['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']))
#                                                                                                     ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %% [markdown]
# # Columns Transformer for all pipeline

# %%
coltrans=ColumnTransformer(transformers=[
    ('xcontpipeline',xcontpipeline,xcont),
    ('xnominalpipeline',xnominalpipeline,xnominal),
    ('xordinalpipeline',xordinalpipeline,xordinal)
],remainder='passthough')

# %% [markdown]
# # Final pipeline

# %%
finalpipeline=Pipeline(steps=[
    ('coltrans',coltrans)
])

# %%
finalpipeline
# Out:
# Pipeline(steps=[('coltrans',
#                  ColumnTransformer(remainder='passthough',
#                                    transformers=[('xcontpipeline',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(),
#                                                                    ('yeojhonson',
#                                                                     PowerTransformer()))]),
#                                                   ['carat', 'depth', 'table',
#                                                    'x', 'y', 'z']),
#                                                  ('xnominalpipeline',
# ...

# %%
from sklearn import set_config
set_config(display="diagram")
finalpipeline
# Out:
# Pipeline(steps=[('coltrans',
#                  ColumnTransformer(remainder='passthough',
#                                    transformers=[('xcontpipeline',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(),
#                                                                    ('yeojhonson',
#                                                                     PowerTransformer()))]),
#                                                   ['carat', 'depth', 'table',
#                                                    'x', 'y', 'z']),
#                                                  ('xnominalpipeline',
# ...
